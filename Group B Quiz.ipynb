# %%
questions_={"question_1":"What is the capital of France?",
            "question_2":"In the UK, the abbreviation NHS stands for National what Service?",
            "question_3":"What is the loudest animal on the Earth",
            "question_4":"Which city in the world has the most diversity in terms of languages spoken",
            "question_5":"What was the first toy ever to be advertised on television",
            "question_6":"Which geometric shape is generally used for stop signs",
            "question_7":"Which South Korean company has the largest annual revenue",
            "question_8":"Which coloured M&M is the rarest",
            "question_9":"What is the only edible food that does not go bad",
            "questoin_10":"How many points did Michael Jordan score in his first NBA game",
            
            
            
            
            
}

answer_op=["a.Paris\nb.Berlin\nc.Tokyo\nd.Cairo\n",
           "a.Health\nb.Humanitarian\nc.Honour\nd.Home",
           "a.Lion\nb.Sperm Whale\nc.Elephant\nd.Blue Whale",
           "a.London\nb.Los Angeles\nc.Vancouver\nd.New York City",
           "a.Thomas-The train engine\nb.Mr Potato Head\nc.Barbie\nd.A teddy bear",
           "a.Hexagon\nb.Circle\nc.Octagon\d.Decagon",
           "a.Samsung\nb.Hyundai\nc.Kia motors\nd.LG",
           "a.Orange\nb.Brown\nc.Yellow\nd.Blue",
           "a.Bread\nb.Mushrooms\c.Honey\d.Fruits",
           "a.30\nb.16\nc.20\d.5"]
            
half_=["a.Paris, c.Cairo",
       "a.Health, b.Humanitarian",
       "b.Sperm Whale, c.Elephant",
       "a.London, d. New York City",
       "b.Mr Potato Head, d. A teddy bear",
       "c.Octagon, d. Decagon",
       "a.Samsung, d. LG",
       "a.Orange, b.Brown", 
       "b.Mushrooms, c.Honey"
       "a.30, b.16"]  

ask_the_audience=["a.70%, b.20%, c.5%, d.5%", 
                  "a.50%, b.40%, c.2%, d.8%",
                  "a.30%, b.35%, c.25%, d.10%",
                  "a.38%, b.15%, c.5%, d.42%",
                  "a.10%, b.45%, c.20%, d.25%", 
                  "a.25%, b.5%, c.40%, d.30%",
                  "a.30%, b.25%, c.20%, d.25%",
                  "a.35%, b.40%, c.20%, d.5%",
                  "a.15%, b.30%, c.50%, d.5%",
                  "a.30%, b.40%, c.20%, d.10%",]

# %%
hints=["50/50","Call a friend", "Ask the audience"]  

def hint(i):
    
    ans=input("What would you like to use? Enter '50/50', 'Call a friend' or 'Ask the audience'")  #Shouldn't be caps sensitive 
    if ans=="50/50" and ans==hints[0] :
        print(half_[i])   #Timer?
        hints[0]="used"
    elif ans=="Call a friend" and ans==hints[1]:
        print("you have 1 minute to ask a friend")   #Timer?
        hints[1]="used"
    elif ans=="Ask the audience" and ans==hints[2]:
        print("The audience says...")
        print(ask_the_audience[i])   
        hints[2]="used"
    else:
        print("This hint has been used or is invalid")


# list with 50/50 and ask the audience hints?

# %%
print("Welcome to the show" + "\nWho Wants to Be a Millionaire!")

# take user name
username = input("What is your name?")
print("Hi", username)
print("")

start_game = input('Are you ready to play? (yes or no) ')
if start_game == 'yes':
    print('\nInstructions:\nFor each question, select the correct answer by choosing a, b, c or d.')

for i in range(10):
    
    answers=["a","a","b","d","b","c","a","b","c","b"]
    money=[100, 200, 300, 20000, 30000, 50000, 100000, 250000, 500000, 1000000]
    
    key = list(questions_)[i]
    print(key)  
        
    
    value = list(questions_.values())[i]
    slice(4)
    print(value)  
    
    key1=answer_op[i]
    print(key1)
    
    hint_choice=input("Would you like to use a hint?, enter 'yes' or 'no'")
    if hint_choice=="yes":
        hint(i)
        answer=input("What is your final answer")
    else:
        print('                             ')
        answer=input("What is your final answer")

    if answer==answers[i]:
        money=money[i]
        print(f"Congrats {username} that is correct you have earned ${money}")
        print("                                                  ")
        
    else:
        print("Unfortunately you didn't get it correct.")
        print("Please make sure to come back and play again!")
    if i < 9:
        continue_game = input(f'Answer the next question for a chance to win more (yes or no) ')
    if continue_game == 'no' or '':
        end_game = input("Are you sure you want to quit the game? ")
        if end_game == 'yes':
            print(f"Congratulations! You are going home with ${money}")
        break
    else:
        continue

    break
# Out:
# Welcome to the show
# Who Wants to Be a Millionaire!

# %%
#Add hints 
#Timer?
#An option to end the game 
#Add questions to the dictionary 
#Format options to display on different lines

# %% [raw]
# #Test
# listp=["Paris","Berlin"]
# for line in listp:
#     print(list)
