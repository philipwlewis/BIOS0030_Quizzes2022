# %%
from time import sleep
import colorama
from colorama import Fore

# %%
con_correct = 0
prize_money = 0
saved_prize_money = 0

print("Welcome to...")
sleep(0.5)
print (Fore.BLUE+" *************************************************")
print(Fore.RESET)
sleep(0.5)
print (" *            { The                              *\n")
sleep(0.5)
print (Fore.CYAN+" *                 Weakest                       *")
print(Fore.RESET)
sleep(0.5)
print (" *                        Link   }               *\n")
sleep(0.5)
print (Fore.BLUE+" *************************************************\n")
print(Fore.RESET)
sleep(0.5)

print ("""Instructions: This quiz contains 12 questions, and has 3 rounds with 4 questions each which focus on different topics.
The more consecutive questions you answer correctly without banking, the more money you earn for a correct answer.\n
BUT, if you don't bank and get a question wrong, the amount of money you earn for a correct answer will decrease!
Good luck!!""")
sleep(2)

sleep(2)

# Round 1 Question 1

print(Fore.MAGENTA+"Round 1. Your topic is anatomy.")
print(Fore.RESET)
sleep(1)
q1_ans = input("Q1: How many bones are there in the human body?")

if q1_ans=="206":
    print(Fore.GREEN+"Correct!")
    print(Fore.RESET)
    con_correct = con_correct + 1
    prize_money = 100*con_correct
    print("You have earned £", 100*con_correct)
    print("Your current money is £", prize_money)
else:
    print(Fore.RED+"Incorrect, the correct answer was 206")
    print(Fore.RESET)
    print("You have earned £0, and your current prize money is £", prize_money)
    con_correct=1


print("\n")    
sleep(1)    

# Round 1 Question 2 
    
print("Onto Question 2.")
sleep(1)
print(input("Do you want to bank? (Y/N)"))
if input == "Y":
    con_correct = 0
    saved_prize_money = prize_money

print("\n")
sleep(0.5)
print("Question 2...")
sleep(1)
q2_ans = input("What is the largest organ in the human body?").upper()

if q2_ans=="SKIN" or q2_ans=="THE SKIN":
    print(Fore.GREEN+"Correct!")
    print(Fore.RESET)
    con_correct = con_correct + 1
    prize_money = 100*con_correct + prize_money
    print("You have earned £", 100*con_correct)
    print("Your current prize money is £", prize_money)
else:
    print(Fore.RED+"Incorrect, the correct answer is the skin!")
    print(Fore.RESET)
    print("You have earned £0, and your current prize money is £", prize_money)
    con_correct=1
    

print("\n")       
sleep(1)
    
# Round 1 Question 3

print("Onto Question 3.")
sleep(1)
print(input("Do you want to bank? (Y/N)"))
if input == "Y":
    con_correct = 0
    saved_prize_money = prize_money

print("\n")
sleep(0.5)
print("Question 3...")
sleep(1)
q2_ans = input("What does the orbital cavity contain?").upper()

if q2_ans=="EYE" or q2_ans=="THE EYE":
    print(Fore.GREEN+"Correct!")
    print(Fore.RESET)
    con_correct = con_correct + 1
    prize_money = 100*con_correct + prize_money
    print("You have earned £", 100*con_correct)
    print("Your current prize money is £", prize_money)
else:
    print(Fore.RED+"Incorrect, the correct answer is the eye!")
    print(Fore.RESET)
    print("You have earned £0, and your current prize money is £", prize_money)
    con_correct=1
    

print("\n")       
sleep(1)

# Round 1 Question 4

print("Onto Question 4.")
sleep(1)
print(input("Do you want to bank? (Y/N)"))
if input == "Y":
    con_correct = 0
    saved_prize_money = prize_money

print("\n")
sleep(0.5)
print("Question 4...")
sleep(1)
q4_ans = input("How many chambers does the human heart have?").upper()

if q4_ans=="FOUR" or q4_ans == "4":
    print(Fore.GREEN+"Correct!")
    print(Fore.RESET)
    con_correct = con_correct + 1
    prize_money = 100*con_correct + prize_money
    print("You have earned £", 100*con_correct)
    print("Your current money is £", prize_money)
else:
    print(Fore.RED+"Incorrect, the correct answer was four!")
    print(Fore.RESET)
    print("You have earned £0, and your saved prize money is £", prize_money)
    con_correct=1

print("\n")      
sleep(1)

print(Fore.YELLOW+f"That is the end of round 1. At the end of this round, you have £{prize_money}")
print(Fore.RESET)

sleep(1)


con_correct = 1


# Round 2 Question 1

print(Fore.MAGENTA+"Round 2. Your topic is ecology.")
print(Fore.RESET)
sleep(1)

q1_2_ans = input("Q1: What are the food levels in an ecosystem called?").upper()

if q1_2_ans=="TROPHIC LEVELS" or q1_2_ans =="TROPHIC":
    print(Fore.GREEN+"Correct!")
    print(Fore.RESET)
    con_correct = con_correct + 1
    prize_money = 100*con_correct +prize_money
    print("You have earned £", 100*con_correct)
    print(f"Your current money is £{prize_money}")
else:
    print(Fore.RED+"Incorrect, the correct answer was Trophic Levels")
    print(Fore.RESET)
    print("You have earned £0, and your current prize money is £", prize_money)
    con_correct=1


print("\n")    
sleep(1)    


# Round 2 Question 2

print("Onto Question 2.")
sleep(1)
print(input("Do you want to bank? (Y/N)"))
if input == "Y":
    con_correct = 0
    saved_prize_money = 0
    
print("\n")
sleep(0.5)
print("Question 2...")
sleep(1)
q2_2_ans = input("The term 'ecology' ws coined in 1866 by a scientist from which country?").upper()

if q2_2_ans=="GERMANY":
    print(Fore.GREEN+"Correct!")
    print(Fore.RESET)
    con_correct = con_correct + 1
    prize_money = 100*con_correct +prize_money
    print("You have earned £", 100*con_correct)
    print(f"Your current prize money is £{prize_money}")
else:
    print(Fore.RED+"Incorrect, the correct answer is Germany!")
    print(Fore.RESET)
    print("You have earned £0, and your current prize money is £", prize_money)
    con_correct=1
    

print("\n")       
sleep(1)

# Round 2 Question 3

print("Onto Question 3.")
sleep(1)
print(input("Do you want to bank? (Y/N)"))
if input == "Y":
    con_correct = 0
    saved_prize_money = prize_money
print("\n")
sleep(0.5)
print("Question 3...")
sleep(1)
q3_2_ans = input("A lion hunts and eats a deer. What is the role of the lion in the ecosystem?").upper()

if q3_2_ans=="PREDATOR" or q3_2_ans == "THE PREDATOR" or q3_2_ans=="A PREDATOR":
    print(Fore.GREEN+"Correct!")
    print(Fore.RESET)
    con_correct = con_correct + 1
    prize_money = 100*con_correct + prize_money
    print("You have earned £", 100*con_correct)
    print(f"Your current prize money is £{prize_money}")
else:
    print(Fore.RED+"Incorrect, the correct answer was a predator!")
    print(Fore.RESET)
    print("You have earned £0, and your current prize money is £", prize_money)
    con_correct=1

print("\n")      
sleep(1)

# Round 2 Question 4

print("Onto Question 4.")
sleep(1)
print(input("Do you want to bank? (Y/N)"))
if input == "Y":
    con_correct = 0
    saved_prize_money = prize_money
print("\n")
sleep(0.5)
print("Question 4...")
sleep(1)
q4_2_ans = input("Which natural process causes a decrease in the pH of the ocean?").upper()

if q4_2_ans=="ACIDIFICATION":
    print(Fore.GREEN+"Correct!")
    print(Fore.RESET)
    con_correct = con_correct + 1
    prize_money = 100*con_correct + prize_money
    print("You have earned £", 100*con_correct)
    print(f"Your current prize money is £{prize_money}")
else:
    print(Fore.RED+"Incorrect, the correct answer was acidification!")
    print(Fore.RESET)
    print("You have earned £0, and your current prize money is £", prize_money)
    con_correct=1

print("\n")      
sleep(1)

print(Fore.YELLOW+f"That is the end of round 2. At the end of this round, you have £{prize_money}")
print(Fore.RESET)
sleep(1)

con_correct = 1

# Round 3 Question 1

print(Fore.MAGENTA+"Round 3. Your topic is genetics.")
print(Fore.RESET)
sleep(1)

q1_3_ans = input("Q1: True or false: In the UK, it is currently legal to patent genes? (Answer using T/F)").upper()

if q1_3_ans=="T":
    print(Fore.GREEN+"Correct!")
    print(Fore.RESET)
    con_correct = con_correct + 1
    prize_money = 100*con_correct +prize_money
    print("You have earned £", 100*con_correct)
    print(f"Your current money is £{prize_money}")
else:
    print(Fore.RED+"Incorrect, the correct answer was True!")
    print(Fore.RESET)
    print("You have earned £0, and your current prize money is £", prize_money)
    con_correct=1


print("\n")    
sleep(1) 


# Round 3 Question 2

print("Onto Question 2.")
sleep(1)
print(input("Do you want to bank? (Y/N)"))
if input == "Y":
    con_correct = 0
    saved_prize_money = 0
    
print("\n")
sleep(0.5)
print("Question 2...")
sleep(1)
q2_3_ans = input("Which amino acid does the 'AUG' start codon code for?").upper()

if q2_3_ans=="METHIONINE":
    print(Fore.GREEN+"Correct!")
    print(Fore.RESET)
    con_correct = con_correct + 1
    prize_money = 100*con_correct +prize_money
    print("You have earned £", 100*con_correct)
    print(f"Your current prize money is £{prize_money}")
else:
    print(Fore.RED+"Incorrect, the correct answer is methionine!")
    print(Fore.RESET)
    print("You have earned £0, and your current prize money is £", prize_money)
    con_correct=1

    
# Round 3 Question 3

print("Onto Question 3.")
sleep(1)
print(input("Do you want to bank? (Y/N)"))
if input == "Y":
    con_correct = 0
    saved_prize_money = prize_money
print("\n")
sleep(0.5)
print("Question 3...")
sleep(1)
q3_3_ans = input("Which DNA base is complementary to Guanine?").upper()

if q3_3_ans=="C" or q3_3_ans == "CYTOSINE":
    print(Fore.GREEN+"Correct!")
    print(Fore.RESET)
    con_correct = con_correct + 1
    prize_money = 100*con_correct + prize_money
    print("You have earned £", 100*con_correct)
    print(f"Your current prize money is £{prize_money}")
else:
    print(Fore.RED+"Incorrect, the correct answer was a Cytosine!")
    print("You have earned £0, and your current prize money is £", prize_money)
    con_correct=1

print("\n")      
sleep(1)

# Round 3 Question 4

print("Onto Question 4.")
sleep(1)
print(input("Do you want to bank? (Y/N)"))
if input == "Y":
    con_correct = 0
    saved_prize_money = prize_money
print("\n")
sleep(0.5)
print("Question 4...")
sleep(1)
q4_3_ans = input("How many chromosomes does the average human have?").upper()

if q4_3_ans=="46":
    print(Fore.GREEN+"Correct!")
    print(Fore.RESET)
    con_correct = con_correct + 1
    prize_money = 100*con_correct + prize_money
    print("You have earned £", 100*con_correct)
    print(f"Your current prize money is £{prize_money}")
else:
    print(Fore.RED+"Incorrect, the correct answer was 46 chromosomes!")
    print(Fore.RESET)
    print("You have earned £0, and your current prize money is £", prize_money)
    con_correct=1

print("\n")      
sleep(1)

print(Fore.YELLOW+f"That is the end of round 3. At the end of this game, you have £{prize_money}")
print(Fore.RESET)
sleep(1)
print ("Thank you for playing 'The Weakest Link' by Anya, Annia and Kavya")
print ("We hope you enjoyed!")
